# %%
import pandas as pd      #IMPORTANTE NO OLVIDAR ヽ(•‿ •)ノ
import numpy as np
pd.set_option("display.max_rows", 9) # Especificar el número de filas a mostrar
from scipy import stats # importando scipy.stats
# %matplotlib inline
import matplotlib.pyplot as plt # importando matplotlib
from matplotlib.ticker import NullFormatter
import seaborn as sns # importando seaborn
import calendar
plt.style.use('seaborn-whitegrid') # Se define el estilo, en este caso se elige la visualización clásica de Matlab

# %% [markdown]
# # PCA RECURSOS
#
# 1. Abrir el archivo
# 2. Separar las variables dependientes de las independientes (RECURSOS) y normalizarlas
# 3. Construcción de las matrices de varianza y covarianza
# 4. Cálculo de los valores propios
# 5. PCA

# %%
#Se importan las librerias necesarias
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %% [markdown]
# 1.Abrir el archivo

# %%
#Se cargan los archivos limpios sin variables repetidas, imputados los datos y sin atípicos

total=pd.read_excel("TOTALULIMPIO2-2016.xlsx",index_col=0) #Recursos:amarillo #Capacidades:rojo #Resultados:azul
total
# Out:
#        ESTABLECIMIENTO  DPTO  CIIU  PERIODO    SOCIOS  PERMANENTE   APRENDIZ  \
# 10471           140767     5  1410     2016  1.665038   14.000000   5.370346
# 10474           140807     5  1410     2016  1.665038   16.000000   5.370346
# 10475           140808     5  1410     2016  1.665038   28.000000   1.000000
# 10476           140809     5  1410     2016  1.665038    1.000000   5.370346
# ...                ...   ...   ...      ...       ...         ...        ...
# 11635           987459     8  1410     2016  2.000000   46.562075   3.000000
# 11636           987465     8  1410     2016  1.665038   40.000000   2.000000
# 11637           987467     8  1410     2016  1.665038   36.000000  12.000000
# 11638           987483     8  1410     2016  1.000000    3.000000   2.000000
#
#         PROD_NAL  PROD_EXT  OBRERO    ...     VALORACTIVOS  PROD_BRUTA  \
# 10471  12.562613    2.2875    14.0    ...          14400.0      223374
# 10474  12.562613    2.2875    15.0    ...          46396.0      289190
# 10475   1.000000    2.2875    27.0    ...          46429.0      656973
# 10476  12.562613    2.2875    18.0    ...          24497.0      516359
# ...          ...       ...     ...    ...              ...         ...
# 11635  12.562613    2.2875    27.0    ...         188741.0     1290356
# 11636  12.562613    2.2875    29.0    ...         465071.0     3679414
# 11637   9.000000    2.2875   260.0    ...        2874293.0    15549225
# 11638  12.562613    2.2875    11.0    ...         300842.0     1284882
#
#        PROD_INDUST     INVERBRUTA  TEMPORALDIRECTO  VAL_AGREGADO  \
# 10471       223374     800.000000        79.846659        209107
# 10474       289190  343423.189677        79.846659        246552
# 10475       656973   39787.000000        79.846659        626118
# 10476       516359   24497.000000        36.000000        439511
# ...            ...            ...              ...           ...
# 11635      1290356   11182.000000        54.000000        790408
# 11636      3679414  343423.189677         8.000000       1476328
# 11637     15550083  503083.000000       400.000000       7454626
# 11638      1284882  343423.189677        18.000000        835716
#
#          MPCOMPRADA  COMPRAS_MP_EXTERIOR  EXPORTACIONES    VENTAS
# 10471  3.252153e+06         5.155038e+06   4.996960e+06    223374
# 10474  2.147500e+04         5.155038e+06   4.996960e+06    289190
# 10475  1.553240e+05         5.155038e+06   4.996960e+06    657023
# 10476  6.641000e+04         5.155038e+06   4.996960e+06    516359
# ...             ...                  ...            ...       ...
# 11635  6.182680e+05         5.155038e+06   4.996960e+06   1100444
# 11636  2.164604e+06         5.155038e+06   4.996960e+06   3300208
# 11637  6.940062e+06         5.155038e+06   1.608454e+06  15443532
# 11638  4.216890e+05         5.155038e+06   1.717450e+05   1180126
#
# [823 rows x 61 columns]

# %% [markdown]
# 2.Separar las variables dependientes de las independientes (RECURSOS) y normalizarlas

# %%
variables = ['INV_MP','INV_PP','INV_PT','INV_PTNOFAB','TOTALINV','MPCOMPRADA','PROD_BRUTA','PROD_INDUST','INVER_TERRENO',
            'INVER_EDIF','INVER_MAQ','INVER_OFICINA','INVER_EQTRANSP','TOTALINVER','VAL_TERRENO','VAL_EDIF','VAL_MAQ',
            'VAL_OFICINA','VAL_EQTRANSP','VALORACTIVOS','INVERBRUTA','GASTOSCARTERA','SEGUROS','VENTAS']

# Separando los Recursos (Varibles independientes)
X=total.loc[:,variables].values 

# Separando el objetivo que es ventas (Variable dependiente)
y=total.loc [:, ['VENTAS']].values 

x_std= StandardScaler().fit_transform(X)

# %%
recursos = pd.DataFrame(data = X, columns = variables).head(823)
recursos
# Out:
#            INV_MP       INV_PP        INV_PT    INV_PTNOFAB      TOTALINV  \
# 0    8.872281e+05  751881.4899  1.245539e+06  852834.702155  2.503561e+06
# 1    8.872281e+05  751881.4899  1.245539e+06  852834.702155  2.503561e+06
# 2    8.872281e+05  751881.4899  1.245539e+06  852834.702155  2.503561e+06
# 3    3.852600e+04  751881.4899  1.245539e+06  852834.702155  3.852600e+04
# ..            ...          ...           ...            ...           ...
# 819  1.477983e+06  751881.4899  1.435000e+04  852834.702155  1.492333e+06
# 820  8.872281e+05  751881.4899  5.510530e+05  852834.702155  5.510530e+05
# 821  7.329380e+05   79984.0000  9.949920e+05   15865.000000  1.823779e+06
# 822  8.911900e+04  751881.4899  1.245539e+06  852834.702155  8.911900e+04
#
#        MPCOMPRADA  PROD_BRUTA  PROD_INDUST  INVER_TERRENO     INVER_EDIF  \
# 0    3.252153e+06    223374.0     223374.0  560033.398417  686757.843923
# 1    2.147500e+04    289190.0     289190.0  560033.398417  686757.843923
# 2    1.553240e+05    656973.0     656973.0  560033.398417  686757.843923
# 3    6.641000e+04    516359.0     516359.0  560033.398417  686757.843923
# ..            ...         ...          ...            ...            ...
# 819  6.182680e+05   1290356.0    1290356.0  560033.398417  686757.843923
# 820  2.164604e+06   3679414.0    3679414.0  560033.398417  686757.843923
# 821  6.940062e+06  15549225.0   15550083.0  560033.398417  246000.000000
# 822  4.216890e+05   1284882.0    1284882.0  560033.398417  686757.843923
#
#         ...       VAL_TERRENO      VAL_EDIF    VAL_MAQ    VAL_OFICINA  \
# 0       ...      1.861905e+06  2.269648e+06    12800.0    1600.000000
# 1       ...      1.861905e+06  2.269648e+06    46396.0  165015.144085
# 2       ...      1.861905e+06  2.269648e+06    45130.0  165015.144085
# 3       ...      1.861905e+06  2.269648e+06    22741.0  165015.144085
# ..      ...               ...           ...        ...            ...
# 819     ...      1.861905e+06  2.269648e+06   163917.0    6425.000000
# 820     ...      1.861905e+06  2.000000e+05    93843.0   14789.000000
# 821     ...      1.861905e+06  2.460000e+05  2049837.0  207837.000000
# 822     ...      1.861905e+06  3.052600e+04    61378.0   80619.000000
#
#       VAL_EQTRANSP  VALORACTIVOS     INVERBRUTA  GASTOSCARTERA       SEGUROS  \
# 0    132514.502622       14400.0     800.000000   8.969314e+06  43511.436095
# 1    132514.502622       46396.0  343423.189677   8.969314e+06  43511.436095
# 2    132514.502622       46429.0   39787.000000   8.969314e+06  43511.436095
# 3    132514.502622       24497.0   24497.000000   8.969314e+06    995.000000
# ..             ...           ...            ...            ...           ...
# 819  132514.502622      188741.0   11182.000000   8.969314e+06  10847.000000
# 820  151500.000000      465071.0  343423.189677   8.969314e+06   4900.000000
# 821  159674.000000     2874293.0  503083.000000   2.444700e+04  34127.000000
# 822   84752.000000      300842.0  343423.189677   8.969314e+06   3149.000000
#
#          VENTAS
# 0      223374.0
# 1      289190.0
# 2      657023.0
# 3      516359.0
# ..          ...
# 819   1100444.0
# 820   3300208.0
# 821  15443532.0
# 822   1180126.0
#
# [823 rows x 24 columns]

# %%
#No hay datos perdidos pues se esta utilizando el archivo de los datos limpios

recursos.isnull().sum() # Saber si hay casos con NA
recursos.dropna(how="all", inplace=True) # Eliminar las observaciones con NA
recursos.columns
# Out:
# Index(['INV_MP', 'INV_PP', 'INV_PT', 'INV_PTNOFAB', 'TOTALINV', 'MPCOMPRADA',
#        'PROD_BRUTA', 'PROD_INDUST', 'INVER_TERRENO', 'INVER_EDIF', 'INVER_MAQ',
#        'INVER_OFICINA', 'INVER_EQTRANSP', 'TOTALINVER', 'VAL_TERRENO',
#        'VAL_EDIF', 'VAL_MAQ', 'VAL_OFICINA', 'VAL_EQTRANSP', 'VALORACTIVOS',
#        'INVERBRUTA', 'GASTOSCARTERA', 'SEGUROS', 'VENTAS'],
#       dtype='object')

# %%
#Se elimina la variable ventas pues X=VARIABLES INDEPENDIENTES=Recursos Tangibles
x=recursos.drop("VENTAS",axis = 1)

y=recursos["VENTAS"]  #Y=VARIABLE DEPENDIENTE= Ventas
names=recursos.columns

X_std= StandardScaler().fit_transform(x) #Normalizando

# %%
plt.figure("Histograma")
recursos.plot.hist(alpha=0.4)
plt.figure("Gráfico de pie",figsize=(5,5))
recursos.VENTAS.value_counts().plot(kind="pie",autopct='%1.1f%%', fontsize=15)
plt.show()

# %% [markdown]
# 3.Construcción de las matrices de varianza y covarianza
#
# Para que se pueda realizar el PCA, es necesario que las variables presenten factores comunes. Es decir, que estén muy correlacionadas entre sí. Los coeficientes de la matriz de correlaciones deben ser grandes en valor absoluto.

# %%
# Matriz de covarianza

mean_vec=np.mean(X_std,axis=0)
cov_mat=(X_std-mean_vec).T.dot((X_std-mean_vec))/(X_std.shape[0]-1)

# %%
#Gráficar en un mapa de calor las covarianzas

corMat=np.asarray(cov_mat)

fig, ax = plt.subplots(figsize=(20,20))#Figsize para aumentar el tamaño
im = ax.imshow(corMat,cmap="RdBu")

# Mostrar las etiquetas de las variables
ax.set_xticks(np.arange(len(names)-1))
ax.set_yticks(np.arange(len(names)-1))
# Asignar los nombres a las etiquetas
ax.set_xticklabels(names[:33])
ax.set_yticklabels(names[:33])

# Rotar los nombres
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop para asignar los valores de las correlaciones en el mapa de calor
for i in range(len(names)-1):
    for j in range(len(names)-1):
        text = ax.text(j, i, round(corMat[i, j],2),
                       ha="center", va="center", color="w")

plt.title("Matriz de covarianzas", fontdict={"fontsize":15}) 
# o de correlación si los datos están normalizados
plt.show()

# %%
#Matriz de covarianzas
plt.subplots(figsize=(20,20))
sns.heatmap(x.corr(), square=True, annot=True, linewidths =0.4)

# %% [markdown]
# 4.Cálculo de los valores propios

# %%
eigen_value, eigen_vector =np.linalg.eig(x.corr()) 
print("Valores propios: \n %s \n" %eigen_value)

#Teniendo en cuenta que no estan ordenados a continuación se ordenan los valores propios
# Out:
# Valores propios:
#  [6.41473475e+00 2.60757711e+00 1.85453638e+00 1.72801028e+00
#  1.16314769e+00 2.85950083e-04 6.84590256e-02 9.34513205e-02
#  1.07942505e-01 1.20560485e-01 1.91107713e-01 1.05629937e+00
#  1.00989356e+00 9.83431793e-01 8.69134192e-01 4.03487581e-01
#  4.35062017e-01 5.09149052e-01 5.44373089e-01 7.94151407e-01
#  6.25852151e-01 7.15550096e-01 7.03802479e-01]

# %%
eigen_value, eigen_vector =np.linalg.eig(x.corr()) 


# Hacer una lista (valor propio, vector propio) #tuplas
eig_pairs = [(np.abs(eigen_value[i]), eigen_vector[:,i]) for i in range(len(eigen_value))]

# Ordenar de mayor a menor
eig_pairs.sort()
eig_pairs.reverse()

# Visualizar valores propios en orden descendente 
print('Valores propios ordenados:')
for i in eig_pairs:
    print(i[0])
# Out:
# Valores propios ordenados:
# 6.414734749322305
# 2.6075771086475807
# 1.8545363828085504
# 1.728010280379219
# 1.1631476945901116
# 1.0562993709185504
# 1.0098935561152054
# 0.9834317927880576
# 0.8691341922548576
# 0.7941514067596473
# 0.715550096163205
# 0.7038024787470014
# 0.6258521507889084
# 0.5443730894839073
# 0.5091490524954789
# 0.4350620171528698
# 0.4034875812031854
# 0.19110771326908518
# 0.12056048466229938
# 0.10794250520998641
# 0.09345132052773066
# 0.06845902562899707
# 0.0002859500832650194

# %%
# Hacer una lista (valor propio, vector propio) #tuplas
eig_pairs = [(np.abs(eigen_value[i]), eigen_vector[i]) for i in range(len(eigen_value))]

# Ordenar de mayor a menor
eig_pairs.sort()
eig_pairs.reverse()

print('Valores propios ordenados con su vector propio:')
eig_pairs
# Out:
# Valores propios ordenados con su vector propio:
# [(6.414734749322305,
#   array([ 0.28688722,  0.12999716,  0.19993039, -0.09252227, -0.0419166 ,
#           0.00237102, -0.0315216 ,  0.49320374, -0.10357259, -0.16877953,
#           0.00822413, -0.0010933 ,  0.25962051,  0.05459515, -0.03158417,
#          -0.46871587, -0.05916116,  0.37188411, -0.33088   , -0.0528362 ,
#           0.05041187, -0.12094048, -0.06826811])),
#  (2.6075771086475807,
#   array([ 0.09590592,  0.08062384,  0.4552267 ,  0.01973243,  0.0989165 ,
#          -0.00388256, -0.0281863 ,  0.03090265, -0.0684859 ,  0.0444433 ,
#          -0.03628987,  0.24740974,  0.24001728,  0.04994076, -0.1271278 ,
#          -0.02512546, -0.13409328, -0.27462163,  0.51880203, -0.42274881,
#           0.17769344, -0.00730919, -0.2148125 ])),
#  (1.8545363828085504,
#   array([ 0.20735929,  0.25547401,  0.33458005, -0.02422771, -0.05584728,
#           0.00345828, -0.03361414,  0.29467179, -0.02809507, -0.09514107,
#           0.07120383,  0.00509186, -0.15306473, -0.17679263, -0.06094003,
#           0.67015068,  0.22532344,  0.11866152, -0.06521981, -0.03905903,
#          -0.30312127,  0.05277204,  0.01942007])),
#  (1.728010280379219,
#   array([-0.02343448, -0.01063895,  0.28923155,  0.17546145,  0.40886564,
#           0.00147139, -0.01438445,  0.0550264 , -0.02783544, -0.00632744,
#           0.01700525, -0.40719819, -0.02406263, -0.26404645, -0.04266989,
#          -0.01391509,  0.0374902 , -0.02618844,  0.17346592,  0.48576454,
#           0.25713656, -0.37520707, -0.01453043])),
#  (1.1631476945901116,
#   array([ 0.28012729,  0.25745973,  0.30028373, -0.06187783,  0.01571807,
#          -0.00299227,  0.09043188, -0.7107986 ,  0.1915542 ,  0.21688417,
#          -0.05529584, -0.00721007,  0.03894395, -0.0711986 , -0.08344185,
#          -0.09442936,  0.07100287,  0.2309648 , -0.25184883, -0.03104077,
#          -0.04292116, -0.05589076, -0.10259248])),
#  (1.0562993709185504,
#   array([-5.14331102e-02, -2.03669286e-01,  3.07823141e-01,  5.80453785e-02,
#           7.60182382e-02, -5.30136982e-04,  7.46777485e-02, -2.13543643e-02,
#          -6.92721908e-02,  2.30254193e-02,  1.21034757e-02,  2.49006800e-03,
#          -3.55051426e-01,  4.54253797e-02,  5.58552490e-01,  1.38961932e-02,
#          -8.00772461e-02,  4.00209779e-02, -1.88257022e-01, -3.86293330e-01,
#           1.93291568e-01, -1.99829529e-01,  3.60813040e-01])),
#  (1.0098935561152054,
#   array([ 0.07847834, -0.13213812,  0.1424547 , -0.11037297, -0.48628167,
#          -0.00165488,  0.03363886, -0.04808459,  0.02045537,  0.01842515,
#          -0.00628983, -0.21964019,  0.3623345 , -0.03439857,  0.50788253,
#           0.1598428 , -0.02257162,  0.12790879,  0.19000797,  0.24655958,
#           0.21687473,  0.2422376 , -0.1396679 ])),
#  (0.9834317927880576,
#   array([ 0.22134121, -0.45860429,  0.13081068, -0.05209568, -0.01340815,
#           0.00347177, -0.77047417, -0.00237344,  0.20041275,  0.09777591,
#          -0.12879417,  0.08167744, -0.13440904,  0.074477  , -0.08736689,
#          -0.00485013,  0.08422715, -0.01573826, -0.06520886,  0.08058176,
#           0.01643972,  0.04251472, -0.05116565])),
#  (0.8691341922548576,
#   array([-0.00512392, -0.08491857,  0.09965981,  0.56938249, -0.11806506,
#           0.00064151, -0.03620167, -0.06950884,  0.0041656 , -0.13825585,
#          -0.02352442,  0.11148209,  0.08784701,  0.01966491,  0.19119696,
#          -0.01395302, -0.40116292, -0.08894174, -0.08085705,  0.12113954,
#          -0.52162113, -0.21535221, -0.23035554])),
#  (0.7941514067596473,
#   array([ 0.26957706, -0.07984002, -0.25250842,  0.35541742,  0.04695252,
#          -0.00173769,  0.15736291,  0.26303937,  0.16931555,  0.64074942,
#          -0.19104274, -0.06534135,  0.04873152, -0.19270184, -0.04996039,
#           0.13264311, -0.15439448,  0.13682573, -0.02794272, -0.16561257,
#           0.14324312,  0.0593626 , -0.01755646])),
#  (0.715550096163205,
#   array([-1.34138910e-01, -1.00435228e-01,  2.88880953e-01,  9.00350698e-02,
#           3.11252654e-01, -1.68153830e-04,  1.36549942e-02, -1.11776405e-02,
#          -2.24299698e-02,  4.50028220e-02, -2.33344773e-03, -7.84418206e-02,
#           3.39467193e-01,  1.77595817e-02, -9.57338587e-02, -1.59174209e-02,
#          -1.68722268e-01, -8.87975587e-02, -1.93018534e-01,  9.85907006e-02,
#          -1.46695606e-01,  5.86001938e-01,  4.48627194e-01])),
#  (0.7038024787470014,
#   array([ 0.22042662,  0.01456476, -0.04807554,  0.06074686,  0.27914835,
#          -0.00119885,  0.0555264 ,  0.00143915,  0.01080922,  0.01492802,
#          -0.03101365, -0.1507432 , -0.21442496,  0.39277209,  0.1880066 ,
#          -0.17254706,  0.13585595,  0.38933801,  0.50658458,  0.02874524,
#          -0.33069762,  0.19314426,  0.02520474])),
#  (0.6258521507889084,
#   array([ 0.22806967, -0.42063279,  0.10025126, -0.09174659, -0.01809871,
#          -0.00110388,  0.45880356, -0.0134236 , -0.17231478, -0.2124656 ,
#          -0.60433623,  0.09717859, -0.10109506,  0.05659979, -0.16480053,
#           0.05181581,  0.09819786, -0.10487949, -0.07155779,  0.132831  ,
#          -0.00477217,  0.01528448, -0.07171836])),
#  (0.5443730894839073,
#   array([ 0.09110357, -0.06181004,  0.00245427, -0.03924868, -0.14721123,
#           0.00111217, -0.00642537, -0.01074368,  0.00294748, -0.02013579,
#           0.02474072, -0.78328894,  0.03299201,  0.26098688, -0.17284028,
#           0.01765978, -0.02079389, -0.29577267, -0.11018697, -0.34513231,
#          -0.14333505, -0.072134  , -0.07502289])),
#  (0.5091490524954789,
#   array([ 0.17628885,  0.17810931,  0.03996144,  0.01692099, -0.02162651,
#          -0.00100412,  0.00671925,  0.07608233,  0.04852123, -0.09837653,
#           0.01334366, -0.09005356, -0.45541582, -0.42351455,  0.16037321,
#          -0.34266783, -0.06394887, -0.3208682 , -0.03257045,  0.01496603,
#           0.00208037,  0.45929697, -0.24391819])),
#  (0.4350620171528698,
#   array([ 0.27333814, -0.11257581, -0.26544669,  0.09950475,  0.15129993,
#           0.00256719, -0.1149733 , -0.2368609 , -0.15490496, -0.49935321,
#           0.10166461, -0.09125624,  0.02659397, -0.21749848, -0.12307638,
#           0.21662127, -0.35998321,  0.30018287,  0.06449317, -0.20817746,
#           0.24025435,  0.11037052,  0.02886069])),
#  (0.4034875812031854,
#   array([ 7.70787603e-02, -7.50148712e-03, -2.39414858e-02,  6.19625346e-01,
#          -1.65021536e-01, -1.80127128e-04, -1.21873137e-02, -7.03564358e-02,
#          -2.13678596e-02, -2.02917803e-01,  7.26294170e-02,  3.30360923e-02,
#           1.27820661e-01, -6.05972997e-04, -4.07095665e-02, -1.26764774e-01,
#           6.48146857e-01, -6.28258839e-02, -1.23943903e-02, -1.12098368e-01,
#           1.79021811e-01,  8.67023860e-02,  1.37011720e-01])),
#  (0.19110771326908518,
#   array([ 0.18629713, -0.46673463,  0.05459604, -0.07529312,  0.12917218,
#          -0.00435265,  0.32187437,  0.02414614,  0.10910753,  0.06565268,
#           0.71270761,  0.12065956,  0.00143447,  0.04048773, -0.05839698,
#           0.01639815,  0.08024207, -0.05514447, -0.08889101,  0.04409138,
#          -0.03227209,  0.02466285, -0.22997981])),
#  (0.12056048466229938,
#   array([-0.09063687,  0.00840442,  0.25360812,  0.17691214, -0.48521103,
#           0.00107527,  0.08736024,  0.01317085, -0.02519672,  0.06837502,
#           0.15395565, -0.00629915, -0.38980599,  0.18878009, -0.4322691 ,
#          -0.06751721, -0.28179097,  0.18899832,  0.13260565,  0.17650356,
#           0.18460639,  0.07901868,  0.20154797])),
#  (0.10794250520998641,
#   array([-0.16344246,  0.1789791 ,  0.03002572,  0.18332119,  0.23888998,
#          -0.00253354, -0.04623508,  0.01773866, -0.13005162,  0.00874637,
#          -0.04329122,  0.01697622, -0.11875776,  0.49329292,  0.0710707 ,
#           0.22649879, -0.02935829,  0.03091124, -0.31253905,  0.0838589 ,
#           0.3496866 ,  0.22911522, -0.48266601])),
#  (0.09345132052773066,
#   array([ 0.3572973 ,  0.12474597, -0.09931637, -0.01744281, -0.02506723,
#          -0.70650225, -0.077413  , -0.05758388, -0.40490633,  0.14727945,
#           0.09834702,  0.06652176,  0.00681108,  0.1234971 ,  0.06368103,
#           0.01763407, -0.04481334, -0.23276466, -0.02095806,  0.16857674,
#           0.01622266, -0.0567718 ,  0.17202794])),
#  (0.06845902562899707,
#   array([ 0.35741267,  0.12439748, -0.09802455, -0.01732538, -0.02304555,
#           0.70763828, -0.06927653, -0.06160927, -0.40180019,  0.15164453,
#           0.10010199,  0.06971352,  0.00852509,  0.12645739,  0.06644916,
#           0.01579434, -0.0444358 , -0.2355658 , -0.01872622,  0.16677507,
#           0.01910264, -0.05391712,  0.16746104])),
#  (0.0002859500832650194,
#   array([ 3.03834738e-01,  2.13550332e-01, -7.10723414e-02, -2.96766431e-03,
#           4.01726146e-02, -1.50850650e-03,  1.04383690e-01,  9.19732597e-02,
#           6.78443124e-01, -2.67491628e-01, -2.37125205e-02,  8.78615620e-02,
#           2.84972594e-02,  2.78808184e-01,  7.66519496e-02,  8.81982207e-02,
#          -1.45104726e-01, -2.62642638e-01, -6.09101226e-04,  1.47067908e-01,
#           1.71792553e-01, -7.77395004e-02,  2.37714448e-01]))]

# %%
Tot = sum(eigen_value)
var_exp = [(i / 23)*100 for i in sorted(eigen_value, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
print('Varianza ordenada:')
var_exp
#Varianza ordenada
# Out:
# Varianza ordenada:
# [27.89015108401002,
#  11.33729177672861,
#  8.063201664385002,
#  7.513088175561822,
#  5.057163889522225,
#  4.592605960515437,
#  4.39084154832698,
#  4.275790403426337,
#  3.778844314151555,
#  3.4528322033028145,
#  3.11108737462263,
#  3.0600107771608758,
#  2.721096307777863,
#  2.366839519495249,
#  2.213691532589039,
#  1.891573987621173,
#  1.7542938313181975,
#  0.8309031011699356,
#  0.5241760202708668,
#  0.4693152400434192,
#  0.40631008925100287,
#  0.29764793751737856,
#  0.0012432612315870406]

# %%
print('Varianza acumulada:')
cum_var_exp
# Out:
# Varianza acumulada:
# array([ 27.89015108,  39.22744286,  47.29064453,  54.8037327 ,
#         59.86089659,  64.45350255,  68.8443441 ,  73.1201345 ,
#         76.89897882,  80.35181102,  83.46289839,  86.52290917,
#         89.24400548,  91.610845  ,  93.82453653,  95.71611052,
#         97.47040435,  98.30130745,  98.82548347,  99.29479871,
#         99.7011088 ,  99.99875674, 100.        ])

# %% [markdown]
# Gráfico de la varianza asociada a cada factor. Se utiliza para determinar cuántos factores deben retenerse. Típicamente el gráfico muestra la clara ruptura entre la pronunciada pendiente de los factores más importantes.

# %%
#El nuúmero de componentes esta determinado por el punto donde se encuentra una clara ruptura o punto de inflexión

plt.plot(cum_var_exp,linestyle="-")
plt.xlabel("Número de componentes")
plt.ylabel("Varianza explicada (%)")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Teniendo en cuenta el gráfico anterior se toman las 9 primeras componentes que explican el 73.166% de la varianza

# %%
M_w=eigen_vector[:,0:9]
Y=X_std.dot(M_w) # Nuevos Y

# %% [markdown]
# 5.PCA

# %%
from sklearn.decomposition import PCA

sklearn_PCA= PCA(n_components=9)
Y_1=sklearn_PCA.fit_transform(X_std)

# %% [markdown]
# En cuanto a las nueve componentes escogidas, la quinta hace referencia al monto de las provisiones hechas por la empresa para cubrir eventuales pérdidas de cartera e inventarios y la séptima comprende las inversiones en activos fijos depreciables o con vida útil limitada y al valor de las pólizas de seguros que los amparan. Por otra parte, la segunda, cuarta, sexta y novena componente presentan valores altos pero negativos en las variables correspondientes a las inversiones en activos fijos dedicados exclusivamente para la elaboración de los productos, al valor contable de los activos fijos no destinados a la venta, a las existencias de productos en proceso o terminados y a los inventarios de elementos que no han sufrido ningún proceso de transformación, respectivamente.
#
# Las tres componentes restantes presentan valores altos tanto positivos como negativos, por ejemplo la primera y la tercera componente confrontan la producción bruta contra el valor contable actual de las edificaciones y las inversiones en activos fijos, y la octava componente contrapone el valor de compra de todos elementos físicamente incorporados a los productos con respecto al costo del inventario de éstos.

# %%
PCArecursos = pd.DataFrame(data = Y_1, columns = ['COMPONENTE_1_RT','COMPONENTE_2_RT','COMPONENTE_3_RT','COMPONENTE_4_RT','COMPONENTE_5_RT','COMPONENTE_6_RT','COMPONENTE_7_RT','COMPONENTE_8_RT','COMPONENTE_9_RT'])
PCArecursos.head(823)
# Out:
#      COMPONENTE_1_RT  COMPONENTE_2_RT  COMPONENTE_3_RT  COMPONENTE_4_RT  \
# 0          -0.548456        -1.175219         1.243671         0.483830
# 1           0.031211         0.224897         1.655431         0.292874
# 2          -0.509823        -1.060858         1.369801         0.487407
# 3          -1.639575        -0.575343         0.805543         0.579792
# ..               ...              ...              ...              ...
# 819        -0.993636        -0.049522         0.819033         0.350969
# 820        -0.494679         0.715400         0.905219        -0.627112
# 821         3.106647        -0.272268        -1.796592        -1.694880
# 822        -1.134811         0.739878         1.062952        -0.576023
#
#      COMPONENTE_5_RT  COMPONENTE_6_RT  COMPONENTE_7_RT  COMPONENTE_8_RT  \
# 0           0.178394         0.615532         0.375080         0.604906
# 1           0.219358         0.505554        -0.450831        -0.009104
# 2           0.125569         0.771088        -0.224428        -0.147624
# 3          -0.325906         0.523809        -0.192033        -0.776798
# ..               ...              ...              ...              ...
# 819        -0.026033         0.358088         1.020760         0.273570
# 820         0.065542         0.326723         0.324850         0.455092
# 821        -1.819961         0.617556         0.419109         0.496630
# 822         0.180772        -0.327526        -0.359344        -0.451493
#
#      COMPONENTE_9_RT
# 0          -0.315585
# 1          -0.127336
# 2          -0.411581
# 3          -0.260319
# ..               ...
# 819        -0.078705
# 820         0.071240
# 821        -3.745393
# 822        -0.088449
#
# [823 rows x 9 columns]

# %%
ventas=total[['VENTAS']].head(823)
ventas
# Out:
#          VENTAS
# 10471    223374
# 10474    289190
# 10475    657023
# 10476    516359
# ...         ...
# 11635   1100444
# 11636   3300208
# 11637  15443532
# 11638   1180126
#
# [823 rows x 1 columns]

# %%
PCArecursos.reset_index(drop=True, inplace=True) 
ventas.reset_index(drop=True, inplace=True) 
PCA_R = pd.concat([ventas,PCArecursos], axis=1)
PCA_R
# Out:
#        VENTAS  COMPONENTE_1_RT  COMPONENTE_2_RT  COMPONENTE_3_RT  \
# 0      223374        -0.548456        -1.175219         1.243671
# 1      289190         0.031211         0.224897         1.655431
# 2      657023        -0.509823        -1.060858         1.369801
# 3      516359        -1.639575        -0.575343         0.805543
# ..        ...              ...              ...              ...
# 819   1100444        -0.993636        -0.049522         0.819033
# 820   3300208        -0.494679         0.715400         0.905219
# 821  15443532         3.106647        -0.272268        -1.796592
# 822   1180126        -1.134811         0.739878         1.062952
#
#      COMPONENTE_4_RT  COMPONENTE_5_RT  COMPONENTE_6_RT  COMPONENTE_7_RT  \
# 0           0.483830         0.178394         0.615532         0.375080
# 1           0.292874         0.219358         0.505554        -0.450831
# 2           0.487407         0.125569         0.771088        -0.224428
# 3           0.579792        -0.325906         0.523809        -0.192033
# ..               ...              ...              ...              ...
# 819         0.350969        -0.026033         0.358088         1.020760
# 820        -0.627112         0.065542         0.326723         0.324850
# 821        -1.694880        -1.819961         0.617556         0.419109
# 822        -0.576023         0.180772        -0.327526        -0.359344
#
#      COMPONENTE_8_RT  COMPONENTE_9_RT
# 0           0.604906        -0.315585
# 1          -0.009104        -0.127336
# 2          -0.147624        -0.411581
# 3          -0.776798        -0.260319
# ..               ...              ...
# 819         0.273570        -0.078705
# 820         0.455092         0.071240
# 821         0.496630        -3.745393
# 822        -0.451493        -0.088449
#
# [823 rows x 10 columns]

# %%
print(sklearn_PCA.explained_variance_ratio_)
# Out:
# [0.27890151 0.11337292 0.08063202 0.07513088 0.05057164 0.04592606
#  0.04390842 0.0427579  0.03778843]

# %%
# Para guardar el Dataframe se utiliza la función to_excel y se especifíca el nombre del archivo

PCA_R.to_excel("PCA_RecursosTangibles.xlsx")
