# %%
import pandas as pd      #IMPORTANTE NO OLVIDAR ヽ(•‿ •)ノ
import numpy as np
pd.set_option("display.max_rows", 10) # Especificar el número de filas a mostrar

# %% [markdown]
# ## Importar datos por años a estudiar
#
# En esta sección...

# %%
data=pd.read_excel("Filtrado2008.xlsx",index_col=0)
data.iloc[:4]
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 145973            145898    11  1810     2008          0          0
# 145979            145904    11  1810     2008          1          1
# 145987            145912    11  1810     2008          0          0
# 145988            145913    11  1741     2008          0          1
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# EMPRESA                                                           ...
# 145973               0              2            0            0   ...
# 145979               5              2            0            0   ...
# 145987               0              0            0            0   ...
# 145988               0              0            0            0   ...
#
#          PROD_BRUTA  PROD_INDUST  INVERBRUTA  TEMPORALDIRECTO  PERMANENTE  \
# EMPRESA
# 145973      3525900      3525900           0                0           2
# ...

# %%
data_2=pd.read_excel("Filtrado2013.xlsx",index_col=0)
data_2
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  periodo  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141849            141633    68  1410     2013          0          0
# 141855            141639    68  1410     2013          0          0
# 141862            141646     5  1410     2013          0          0
# 141894            141678    11  1410     2013          0          1
# 141896            141680    76  1410     2013          1          1
# ...                  ...   ...   ...      ...        ...        ...
# 987508            987508     8  1410     2013          0          0
# 987522            987522     8  1392     2013          0          0
# 987525            987525     8  1392     2013          0          0
# 987528            987528     8  1394     2013          1          0
# 987529            987529     8  1394     2013          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# ...

# %%
data["periodo"]=2008
data.drop("Ano",axis=1)
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 145973            145898    11  1810     2008          0          0
# 145979            145904    11  1810     2008          1          1
# 145987            145912    11  1810     2008          0          0
# 145988            145913    11  1741     2008          0          1
# 145997            145922    11  1810     2008          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987508            987508     8  1810     2008          0          0
# 987522            987522     8  1741     2008          0          0
# 987525            987525     8  1741     2008          0          0
# 987528            987528     8  1743     2008          0          1
# 987529            987529     8  1743     2008          0          1
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# ...

# %%
data.append(data_2)
# Out:
# C:\Users\EEIE\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
#          ADM_HOM  ADM_MUJ  APRENDIZHOM  APRENDIZMUJ   Ano  CIIU  \
# EMPRESA
# 145973         1        0            0            0  2008  1810
# 145979         2        4            0            0  2008  1810
# 145987         2        3            0            0  2008  1810
# 145988         0        0            0            0  2008  1741
# 145997         0        4            0            0  2008  1810
# ...          ...      ...          ...          ...   ...   ...
# 987508         2        0            0            0  2013  1410
# 987522        14       31            1            3  2013  1392
# ...
