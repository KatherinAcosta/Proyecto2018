# %%
import pandas as pd      #IMPORTANTE NO OLVIDAR ヽ(•‿ •)ノ
import numpy as np
pd.set_option("display.max_rows", 5) # Especificar el número de filas a mostrar

# %% [markdown]
# # Importar datos por años a estudiar
# En esta sección se importan los datos a utilizar en investigación (Los datos estan divididos por años de 2008-2016)

# %%
data=pd.read_excel("Filtrado2008.xlsx",index_col=0)
data
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 145973            145898    11  1810     2008          0          0
# 145979            145904    11  1810     2008          1          1
# ...                  ...   ...   ...      ...        ...        ...
# 987528            987528     8  1743     2008          0          1
# 987529            987529     8  1743     2008          0          1
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# EMPRESA                                                           ...
# 145973               0              2            0            0   ...
# 145979               5              2            0            0   ...
# ...                ...            ...          ...          ...   ...
# 987528               4              6            0            1   ...
# 987529               4              6            0            1   ...
#
# ...

# %%
print(data.info()) # Obtener información del DataFrame

# %%
# Para conocer cuál es la posición del valor más alto dentro de una columna se usa la función idx.max() ヽ(•‿ •)ノ

print("Las mayores ventas son de: $ %s" % data.loc[data.VENTAS.idxmax()].VENTAS)
# Out:
# Las mayores ventas son de: $ 249164227

# %%
data_2=pd.read_excel("Filtrado2009.xlsx",index_col=0)
data_2
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 143927            143901    54  1810     2009          1          0
# 143930            143904     5  1741     2009          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987528            987528     8  1743     2009          0          1
# 987529            987529     8  1743     2009          0          1
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# EMPRESA                                                           ...
# 143927               0              0            0            0   ...
# 143930               1              8            0            0   ...
# ...                ...            ...          ...          ...   ...
# 987528               4              6            0            1   ...
# 987529               4              6            0            1   ...
#
# ...

# %%
data_3=pd.read_excel("Filtrado2010.xlsx",index_col=0)
data_3
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 142363            142274    76  1730     2010          1          1
# 142364            142275    76  1810     2010          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987528            987528     8  1743     2010          2          1
# 987529            987529     8  1743     2010          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# EMPRESA                                                           ...
# 142363               0              0            0            0   ...
# 142364               0              0            0            0   ...
# ...                ...            ...          ...          ...   ...
# 987528               1              1            0            0   ...
# 987529              11             16            0            2   ...
#
# ...

# %%
data_4=pd.read_excel("Filtrado2011.xlsx",index_col=0)
data_4
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 142363            142274    76  1730     2011          1          1
# 142364            142275    76  1810     2011          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987528            987528     8  1743     2011          0          0
# 987529            987529     8  1743     2011          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# EMPRESA                                                           ...
# 142363               0              0            0            0   ...
# 142364               0              0            0            0   ...
# ...                ...            ...          ...          ...   ...
# 987528              11             22            1            1   ...
# 987529              11             22            1            1   ...
#
# ...

# %%
data_5=pd.read_excel("Filtrado2012.xlsx",index_col=0)
data_5
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 142363            142274    76  1313     2012          1          1
# 142364            142275    76  1410     2012          4          0
# ...                  ...   ...   ...      ...        ...        ...
# 987528            987528     8  1394     2012          2          1
# 987529            987529     8  1394     2012          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# EMPRESA                                                           ...
# 142363               0              0            0            0   ...
# 142364               0              1            0            0   ...
# ...                ...            ...          ...          ...   ...
# 987528               2              1            0            0   ...
# 987529              14             29            0            1   ...
#
# ...

# %%
data_6=pd.read_excel("Filtrado2013.xlsx",index_col=0)
data_6
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141849            141633    68  1410     2013          0          0
# 141855            141639    68  1410     2013          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987528            987528     8  1394     2013          1          0
# 987529            987529     8  1394     2013          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM   ...     \
# EMPRESA                                                           ...
# 141849               4              2            0            0   ...
# 141855               3              0            0            0   ...
# ...                ...            ...          ...          ...   ...
# 987528               0              1            0            0   ...
# 987529               9             15            0            1   ...
#
# ...

# %%
data_7=pd.read_excel("Filtrado2014.xlsx",index_col=0)
data_7
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141849            141633    68  1410     2014          0          1
# 141855            141639    68  1410     2014          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987525            987525     8  1392     2014          0          0
# 987529            987529     8  1394     2014          1          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 141849               4              0            0            0    ...
# 141855               3              2            0            0    ...
# ...                ...            ...          ...          ...    ...
# 987525              11              5            2            1    ...
# 987529              12             22            2            1    ...
#
# ...

# %%
data_8=pd.read_excel("Filtrado2015.xlsx",index_col=0)
data_8
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141802            977368     5  1410     2015          0          0
# 141812            145789    11  1410     2015          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987525            987525     8  1392     2015          0          0
# 987529            987529     8  1394     2015          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 141802             370             41           13            6    ...
# 141812               3              0            1            1    ...
# ...                ...            ...          ...          ...    ...
# 987525              12              9            3            1    ...
# 987529               6             12            1            1    ...
#
# ...

# %%
data_9=pd.read_excel("Filtrado2016.xlsx",index_col=0)
data_9
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141532            140711     5  1410     2016          0          0
# 141553            140747    11  1410     2016          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987530            987530     8   139     2016          0          0
# 987533            987533     8   139     2016          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...      \
# EMPRESA                                                            ...
# 141532              68             38            8            2    ...
# 141553             449            801            5            1    ...
# ...                ...            ...          ...          ...    ...
# 987530              33             32            2            1    ...
# 987533               5              5            1            1    ...
#
# ...

# %%
data.append([data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9])
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 145973            145898    11  1810     2008          0          0
# 145979            145904    11  1810     2008          1          1
# ...                  ...   ...   ...      ...        ...        ...
# 987530            987530     8   139     2016          0          0
# 987533            987533     8   139     2016          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 145973               0              2            0            0    ...
# 145979               5              2            0            0    ...
# ...                ...            ...          ...          ...    ...
# 987530              33             32            2            1    ...
# 987533               5              5            1            1    ...
#
# ...
