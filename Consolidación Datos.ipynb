# %%
import pandas as pd      #IMPORTANTE NO OLVIDAR ヽ(•‿ •)ノ
import numpy as np
pd.set_option("display.max_rows", 9) # Especificar el número de filas a mostrar
from scipy import stats # importando scipy.stats
# %matplotlib inline
import matplotlib.pyplot as plt # importando matplotlib
from matplotlib.ticker import NullFormatter
import seaborn as sns # importando seaborn
import calendar
plt.style.use('seaborn-whitegrid') # Se define el estilo, en este caso se elige la visualización clásica de Matlab

# %% [markdown]
# # Importar datos por años a estudiar
# En esta sección se importan los datos a utilizar en investigación (Los datos estan divididos por años de 2008-2016)

# %%
data=pd.read_excel("Filtrado2008.xlsx",index_col=0)
data
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 145973            145898    11  1810     2008          0          0
# 145979            145904    11  1810     2008          1          1
# 145987            145912    11  1810     2008          0          0
# 145988            145913    11  1741     2008          0          1
# ...                  ...   ...   ...      ...        ...        ...
# 987522            987522     8  1741     2008          0          0
# 987525            987525     8  1741     2008          0          0
# 987528            987528     8  1743     2008          0          1
# 987529            987529     8  1743     2008          0          1
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 145973               0              2            0            0    ...
# ...

# %%
# Para conocer cuál es la posición del valor más alto dentro de una columna se usa la función idx.max() ヽ(•‿ •)ノ

print("Las mayores ventas son de: $ %s" % data.loc[data.VENTAS.idxmax()].VENTAS)
# Out:
# Las mayores ventas son de: $ 249164227

# %%
data_2=pd.read_excel("Filtrado2009.xlsx",index_col=0)
data_2
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 143927            143901    54  1810     2009          1          0
# 143930            143904     5  1741     2009          0          0
# 143953            143927     5  1810     2009          0          0
# 143957            143931     5  1810     2009          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987522            987522     8  1741     2009          0          0
# 987525            987525     8  1741     2009          0          0
# 987528            987528     8  1743     2009          0          1
# 987529            987529     8  1743     2009          0          1
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 143927               0              0            0            0    ...
# ...

# %%
data_3=pd.read_excel("Filtrado2010.xlsx",index_col=0)
data_3
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 142363            142274    76  1730     2010          1          1
# 142364            142275    76  1810     2010          0          0
# 142366            142277    76  1810     2010          0          1
# 142373            142284    76  1810     2010          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987522            987522     8  1741     2010          0          0
# 987525            987525     8  1741     2010          0          0
# 987528            987528     8  1743     2010          2          1
# 987529            987529     8  1743     2010          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 142363               0              0            0            0    ...
# ...

# %%
data_4=pd.read_excel("Filtrado2011.xlsx",index_col=0)
data_4
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 142363            142274    76  1730     2011          1          1
# 142364            142275    76  1810     2011          0          0
# 142366            142277    76  1810     2011          0          1
# 142373            142284    76  1810     2011          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987522            987522     8  1741     2011          0          0
# 987525            987525     8  1741     2011          0          0
# 987528            987528     8  1743     2011          0          0
# 987529            987529     8  1743     2011          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 142363               0              0            0            0    ...
# ...

# %%
data_5=pd.read_excel("Filtrado2012.xlsx",index_col=0)
data_5
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 142363            142274    76  1313     2012          1          1
# 142364            142275    76  1410     2012          4          0
# 142366            142277    76  1410     2012          0          0
# 142373            142284    76  1410     2012          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987522            987522     8  1392     2012          0          0
# 987525            987525     8  1392     2012          0          0
# 987528            987528     8  1394     2012          2          1
# 987529            987529     8  1394     2012          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 142363               0              0            0            0    ...
# ...

# %%
data_6=pd.read_excel("Filtrado2013.xlsx",index_col=0)
data_6
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141849            141633    68  1410     2013          0          0
# 141855            141639    68  1410     2013          0          0
# 141862            141646     5  1410     2013          0          0
# 141894            141678    11  1410     2013          0          1
# ...                  ...   ...   ...      ...        ...        ...
# 987522            987522     8  1392     2013          0          0
# 987525            987525     8  1392     2013          0          0
# 987528            987528     8  1394     2013          1          0
# 987529            987529     8  1394     2013          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 141849               4              2            0            0    ...
# ...

# %%
data_7=pd.read_excel("Filtrado2014.xlsx",index_col=0)
data_7
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141849            141633    68  1410     2014          0          1
# 141855            141639    68  1410     2014          0          0
# 141862            141646     5  1410     2014          0          0
# 141894            141678    11  1410     2014          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987508            987508     8  1410     2014          0          0
# 987522            987522     8  1392     2014          0          0
# 987525            987525     8  1392     2014          0          0
# 987529            987529     8  1394     2014          1          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 141849               4              0            0            0    ...
# ...

# %%
data_8=pd.read_excel("Filtrado2015.xlsx",index_col=0)
data_8
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141802            977368     5  1410     2015          0          0
# 141812            145789    11  1410     2015          0          0
# 141815            141077     5  1410     2015          0          0
# 141823            141094     5  1410     2015          1          0
# ...                  ...   ...   ...      ...        ...        ...
# 987483            987483     8  1410     2015          0          1
# 987522            987522     8  1392     2015          0          0
# 987525            987525     8  1392     2015          0          0
# 987529            987529     8  1394     2015          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 141802             370             41           13            6    ...
# ...

# %%
data_9=pd.read_excel("Filtrado2016.xlsx",index_col=0)
data_9
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 141532            140711     5  1410     2016          0          0
# 141553            140747    11  1410     2016          0          0
# 141559            140753    11   139     2016          0          0
# 141573            140767     5  1410     2016          0          0
# ...                  ...   ...   ...      ...        ...        ...
# 987525            987525     8   139     2016          0          0
# 987529            987529     8   139     2016          0          0
# 987530            987530     8   139     2016          0          0
# 987533            987533     8   139     2016          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...      \
# EMPRESA                                                            ...
# 141532              68             38            8            2    ...
# ...

# %% [markdown]
# # Unificar todos los años en una sola base de datos
#
# Se utiliza la función .append y el total de datos es de 11645 (11645 empresas)

# %%
total=data.append([data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9]) #Se unifica en base de datos "total"
total
# Out:
#          ESTABLECIMIENTO  DPTO  CIIU  PERIODO  SOCIOSMUJ  SOCIOSHOM  \
# EMPRESA
# 145973            145898    11  1810     2008          0          0
# 145979            145904    11  1810     2008          1          1
# 145987            145912    11  1810     2008          0          0
# 145988            145913    11  1741     2008          0          1
# ...                  ...   ...   ...      ...        ...        ...
# 987525            987525     8   139     2016          0          0
# 987529            987529     8   139     2016          0          0
# 987530            987530     8   139     2016          0          0
# 987533            987533     8   139     2016          0          0
#
#          PERMANENTEMUJ  PERMANENTEHOM  APRENDIZMUJ  APRENDIZHOM    ...     \
# EMPRESA                                                            ...
# 145973               0              2            0            0    ...
# ...

# %%
print(total.info()) # Obtener información del DataFrame Unificado

# %%
# Para guardar el Dataframe se utiliza la función to_excel y se especifíca el nombre del archivo

total.to_excel("TOTAL.xlsx")

# %% [markdown]
# # Análisis Exploratorio de los datos
#
# Los estadísticos descriptivos más habitualmente utilizados han sido la media y la desviación típica. Sin embargo, el uso automático de estos índices no es muy aconsejable. Se hallan los valores máximos, media, mediana (percentil 50%), moda, desviación típica, varianza, percentil inferior 25% y percentil superior 75%

# %%
maximos = total.max() #Serie que contiene los valores máximos de cada columna con función max()
maximos
# Out:
# ESTABLECIMIENTO           987533
# DPTO                          76
# CIIU                        1810
# PERIODO                     2016
#                          ...
# MPCOMPRADA             387460640
# COMPRAS_MP_EXTERIOR    141580839
# EXPORTACIONES          194416648
# VENTAS                 464467863
# Length: 75, dtype: int64

# %%
media=total.mean() # media aritmetica de cada columna con función función mean()   “No se por qué aparece así  ?????”
media
# Out:
# ESTABLECIMIENTO        5.018258e+05
# DPTO                   2.084173e+01
# CIIU                   1.549005e+03
# PERIODO                2.011981e+03
#                            ...
# MPCOMPRADA             3.135137e+06
# COMPRAS_MP_EXTERIOR    7.304261e+05
# EXPORTACIONES          1.274879e+06
# VENTAS                 7.581216e+06
# Length: 75, dtype: float64

# %%
mediana=total.median() # mediana de cada columna utilizando la función median() 
mediana
# Out:
# ESTABLECIMIENTO         217217.0
# DPTO                        11.0
# CIIU                      1410.0
# PERIODO                   2012.0
#                          ...
# MPCOMPRADA              530365.0
# COMPRAS_MP_EXTERIOR          0.0
# EXPORTACIONES                0.0
# VENTAS                 1464990.0
# Length: 75, dtype: float64

# %%
stats.mode(total) # Moda de cada columna # el 2do array devuelve la frecuencia.

# %%
desvtipica=np.std(total, 0) # Desviación típica de cada columna utilizando la función std ()
desvtipica
# Out:
# ESTABLECIMIENTO        3.886233e+05
# DPTO                   2.564409e+01
# CIIU                   2.897916e+02
# PERIODO                2.496968e+00
#                            ...
# MPCOMPRADA             1.263802e+07
# COMPRAS_MP_EXTERIOR    5.072078e+06
# EXPORTACIONES          6.979826e+06
# VENTAS                 2.666381e+07
# Length: 75, dtype: float64

# %%
varianza=np.var(total, 0) # varianza de cada columna utilizando la función var()
varianza
# Out:
# ESTABLECIMIENTO        1.510281e+11
# DPTO                   6.576193e+02
# CIIU                   8.397918e+04
# PERIODO                6.234848e+00
#                            ...
# MPCOMPRADA             1.597197e+14
# COMPRAS_MP_EXTERIOR    2.572597e+13
# EXPORTACIONES          4.871797e+13
# VENTAS                 7.109587e+14
# Length: 75, dtype: float64

# %%
resumenestad=total.describe() # resumen estadistadistico con pandas 
resumenestad #cantidad,media,desviación, mímino, percentil inferior, 50% o mediana, percentil superior, máximo
# Out:
#        ESTABLECIMIENTO          DPTO          CIIU       PERIODO  \
# count     11645.000000  11645.000000  11645.000000  11645.000000
# mean     501825.836926     20.841735   1549.005067   2011.981022
# std      388639.971086     25.645191    289.804063      2.497075
# min      140711.000000      5.000000     13.000000   2008.000000
# 25%      144700.000000      5.000000   1410.000000   2010.000000
# 50%      217217.000000     11.000000   1410.000000   2012.000000
# 75%      976117.000000     11.000000   1810.000000   2014.000000
# max      987533.000000     76.000000   1810.000000   2016.000000
#
#           SOCIOSMUJ     SOCIOSHOM  PERMANENTEMUJ  PERMANENTEHOM   APRENDIZMUJ  \
# count  11645.000000  11645.000000   11645.000000   11645.000000  11645.000000
# mean       0.197681      0.212108      20.967626      16.038128      1.406956
# std        0.519372      0.512477      53.675724      61.315094      4.273062
# ...

# %% [markdown]
# # Manipulación de datos perdidos
#
# Para contar los valores missing, Nan o None se utiliza el comando sample y se crea la variable isnull().sum() para contarlo
#
# Se observa que no hay datos perdidos

# %%
total.sample(10) #Contar los valores perdidos en cada columna
missing_values_count = total.isnull().sum()
missing_values_count[0:75] #No hay datos perdidos en ninguna columna
# Out:
# ESTABLECIMIENTO                 0
# DPTO                            0
# CIIU                            0
# PERIODO                         0
# SOCIOSMUJ                       0
# SOCIOSHOM                       0
# PERMANENTEMUJ                   0
# PERMANENTEHOM                   0
# APRENDIZMUJ                     0
# APRENDIZHOM                     0
# PROD_NAL_MUJ                    0
# PROD_NAL_HOM                    0
# PROD_EXT_MUJ                    0
# PROD_EXT_HOM                    0
# OBREROMUJ                       0
# OBREROHOM                       0
# ADM_MUJ                         0
# ADM_HOM                         0
# TOTMUJER                        0
# TOTHOMBRE                       0
# COSTOS_PT_ELAB_TERCEROS         0
# OUTSOURCING_PROD                0
# OUTSOURCING_ADM                 0
# TOTAL_OUTSOURCING               0
# MUESTRASGRATIS_PROD             0
# MUESTRASGRATIS_ADM              0
# TOT_MUESTRASGRATIS              0
# ...

# %% [markdown]
# # Datos Atípicos
# Un valor atípico es una observación que se aleja demasiado de la moda; esta muy lejos de la tendencia principal del resto de los datos. Pueden ser causados por errores en la recolección de datos o medidas inusuales. Generalmente se recomienda eliminarlos del conjunto de datos.
#
# Los diagramas de cajas son una presentación visual que describe varias características importantes al mismo tiempo, tales como la dispersión y simetría. Para su realización se representan los tres cuartiles y los valores mínimo y máximo de los datos, sobre un rectángulo, alineado horizontal o verticalmente. Estos gráficos nos proporcionan abundante información y son sumamente útiles para encontrar valores atípicos y comparar dos conjunto de datos.

# %%
# Ejemplo de grafico de cajas en python

SOCIOSMUJ = np.random.normal(100, 10, 200)
SOCIOSHOM = np.random.normal(80, 30, 200)
PERMANENTEMUJ = np.random.normal(90, 20, 200)
PERMANENTEHOM = np.random.normal(70, 25, 200)

datos_graf = [datos_1, datos_2, datos_3, datos_4]

# Creando el objeto figura
fig = plt.figure(1, figsize=(9, 6))

# Creando el subgrafico
ax = fig.add_subplot(111)

# creando el grafico de cajas
bp = ax.boxplot(datos_graf)

# visualizar mas facile los atípicos
for flier in bp['fliers']:
    flier.set(marker='o', color='red', alpha=0.5)
# los puntos aislados son valores atípicos
