# %%
#Se importan las librerias

# %matplotlib inline

import pandas as pd 
import numpy as np
from scipy import stats # importando scipy.stats
import matplotlib.pyplot as plt # importando matplotlib
from matplotlib.ticker import NullFormatter
import seaborn as sns # importando seaborn
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import calendar
from statsmodels.formula.api import ols
from sklearn.cluster import KMeans
pd.set_option("display.max_rows", 9) # Especificar el número de filas a mostrar
plt.style.use('seaborn-whitegrid') # Se define el estilo, en este caso se elige la visualización clásica de Matlab

# %%
#Se cargan los archivos 

total=pd.read_excel("NORMALIZADO2008.xlsx",index_col=0) 
total
# Out:
#          APRENDIZ   OBRERO  COSTOS_PT_ELAB_TERCEROS  OUTSOURCING_PROD  \
# PERIODO
# 2008      0.38277 -0.15800                 -0.77895           0.12825
# 2008      0.38277 -0.66186                 -0.84376           0.12825
# 2008      0.38277 -0.40993                 -0.83658           0.12825
# 2008      0.38277 -0.62310                 -0.70373           0.12825
# ...           ...      ...                      ...               ...
# 2008     -1.26257  0.11330                  0.51296           0.12825
# 2008     -1.26257  0.11330                  0.51296           0.12825
# 2008      0.38277 -0.58434                 -0.82027           0.12825
# 2008     -0.28621  0.22958                 -0.42884           0.12825
#
#          COMPRAS_MP_EXTERIOR  PUBLICIDAD_PROD  GASTOSCARTERA  SEGUROS  \
# PERIODO
# 2008                 0.26653          0.13428       -1.98759 -0.67421
# 2008                 0.26653          0.13428       -1.98759  0.74989
# 2008                 0.26653          0.13428       -1.98759 -0.78964
# 2008                 0.26653          0.13428       -1.98759 -0.63447
# ...                      ...              ...            ...      ...
# 2008                -3.11099         -2.82082       -1.98435 -0.41430
# 2008                -3.11099         -2.82082       -1.98435 -0.41430
# 2008                 0.26653          0.13428       -1.98435 -0.63473
# 2008                 0.26653          0.13428       -1.98434 -0.04401
#
#          TOTALINV_EINFORMATICA  TOTALINVER   INV_PT  MPCOMPRADA   VENTAS
# PERIODO
# 2008                  -1.47777    -0.80595 -0.25338    -0.14701 -0.37811
# 2008                   0.52437     0.63655 -0.81886    -0.50491 -0.52918
# 2008                   0.52437     0.63655 -0.31512    -0.47865 -0.51992
# 2008                   0.52437     0.63655 -0.80717    -0.09377 -0.00835
# ...                        ...         ...      ...         ...      ...
# 2008                  -1.58141    -0.51598 -0.69069    -0.05244  0.01615
# 2008                  -1.58141    -0.51598 -0.69069    -0.05244  0.01615
# 2008                  -1.46270    -0.92662  0.74202    -0.32284 -0.37985
# 2008                   0.52437    -0.96332  0.77998     0.29061  0.33653
#
# [942 rows x 13 columns]

# %%
#Se establecen las variables independientes
X = total.drop(["VENTAS"],axis=1).as_matrix()
variables = total.drop("VENTAS",axis=1).columns

#Se establecen la variable dependiente = VENTAS
y = total["VENTAS"]
scale = StandardScaler()
# Out:
# C:\Users\Invitado\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
#Se escribe la fórmula del modelo regresivo

formula = "VENTAS ~ APRENDIZ + OBRERO  + COSTOS_PT_ELAB_TERCEROS + OUTSOURCING_PROD + COMPRAS_MP_EXTERIOR + PUBLICIDAD_PROD + GASTOSCARTERA  + SEGUROS  + TOTALINVER + INV_PT + MPCOMPRADA"

# %%
#Se ejecuta el modelo

est = ols(formula, total).fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 VENTAS   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     466.5
# Date:                Fri, 15 Mar 2019   Prob (F-statistic):               0.00
# Time:                        18:39:04   Log-Likelihood:                -609.22
# No. Observations:                 942   AIC:                             1242.
# Df Residuals:                     930   BIC:                             1301.
# Df Model:                          11
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  58.5263     31.556      1.855      0.064      -3.403     120.455
# APRENDIZ                    0.0218      0.015      1.460      0.145      -0.007       0.051
# OBRERO                      0.2128      0.018     11.681      0.000       0.177       0.249
# COSTOS_PT_ELAB_TERCEROS     0.0710      0.018      3.970      0.000       0.036       0.106
# OUTSOURCING_PROD           -0.0464      0.018     -2.539      0.011      -0.082      -0.011
# COMPRAS_MP_EXTERIOR        -0.0230      0.013     -1.748      0.081      -0.049       0.003
# PUBLICIDAD_PROD             0.0477      0.012      4.024      0.000       0.024       0.071
# GASTOSCARTERA              29.4080     15.886      1.851      0.064      -1.769      60.585
# SEGUROS                     0.1237      0.019      6.362      0.000       0.086       0.162
# TOTALINVER                  0.1305      0.012     11.247      0.000       0.108       0.153
# INV_PT                      0.0909      0.021      4.246      0.000       0.049       0.133
# MPCOMPRADA                  0.7920      0.021     37.034      0.000       0.750       0.834
# ==============================================================================
# Omnibus:                      687.558   Durbin-Watson:                   1.609
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25196.967
# Skew:                           2.884   Prob(JB):                         0.00
# Kurtosis:                      27.672   Cond. No.                     5.29e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#Teniendo en cuenta que el modelo anterior presenta heterocedasticidad se usa el Estimador Robusto de a la heterocedasticidad de White desarrollado en 1980 

#Se ejecuta el modelo final

est = ols(formula, total).fit(cov_type='HC0') #HCO=Heterocedasticidad usando Estimador de White

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 VENTAS   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     142.7
# Date:                Fri, 15 Mar 2019   Prob (F-statistic):          5.52e-191
# Time:                        18:39:08   Log-Likelihood:                -609.22
# No. Observations:                 942   AIC:                             1242.
# Df Residuals:                     930   BIC:                             1301.
# Df Model:                          11
# Covariance Type:                  HC0
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  58.5263     39.521      1.481      0.139     -18.933     135.986
# APRENDIZ                    0.0218      0.015      1.441      0.150      -0.008       0.051
# OBRERO                      0.2128      0.027      7.845      0.000       0.160       0.266
# COSTOS_PT_ELAB_TERCEROS     0.0710      0.026      2.700      0.007       0.019       0.123
# OUTSOURCING_PROD           -0.0464      0.024     -1.930      0.054      -0.094       0.001
# COMPRAS_MP_EXTERIOR        -0.0230      0.017     -1.326      0.185      -0.057       0.011
# PUBLICIDAD_PROD             0.0477      0.006      7.486      0.000       0.035       0.060
# GASTOSCARTERA              29.4080     19.894      1.478      0.139      -9.583      68.399
# SEGUROS                     0.1237      0.038      3.224      0.001       0.049       0.199
# TOTALINVER                  0.1305      0.042      3.079      0.002       0.047       0.214
# INV_PT                      0.0909      0.027      3.381      0.001       0.038       0.144
# MPCOMPRADA                  0.7920      0.048     16.644      0.000       0.699       0.885
# ==============================================================================
# Omnibus:                      687.558   Durbin-Watson:                   1.609
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25196.967
# Skew:                           2.884   Prob(JB):                         0.00
# Kurtosis:                      27.672   Cond. No.                     5.29e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The condition number is large, 5.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
