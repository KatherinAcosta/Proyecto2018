# %%
#Se importan las librerias

# %matplotlib inline

import pandas as pd 
import numpy as np
from scipy import stats # importando scipy.stats
import matplotlib.pyplot as plt # importando matplotlib
from matplotlib.ticker import NullFormatter
import seaborn as sns # importando seaborn
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import calendar
from statsmodels.formula.api import ols
from sklearn.cluster import KMeans
pd.set_option("display.max_rows", 9) # Especificar el número de filas a mostrar
plt.style.use('seaborn-whitegrid') # Se define el estilo, en este caso se elige la visualización clásica de Matlab

# %%
#Se cargan los archivos 

total=pd.read_excel("NORMALIZADO2014.xlsx",index_col=0)

# %%
#Se establecen las variables independientes
X = total.drop(["VENTAS"],axis=1).as_matrix()
variables = total.drop("VENTAS",axis=1).columns

#Se establecen la variable dependiente = VENTAS
y = total["VENTAS"]
scale = StandardScaler()
# Out:
# C:\Users\Invitado\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
#Se escribe la fórmula del modelo regresivo

formula = "VENTAS ~ APRENDIZ + OBRERO  + COSTOS_PT_ELAB_TERCEROS + OUTSOURCING_PROD + COMPRAS_MP_EXTERIOR + PUBLICIDAD_PROD + GASTOSCARTERA  + SEGUROS  + TOTALINVER + INV_PT + MPCOMPRADA"

# %%
#Se ejecuta el modelo

est = ols(formula, total).fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 VENTAS   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     463.8
# Date:                Mon, 04 Mar 2019   Prob (F-statistic):               0.00
# Time:                        11:52:42   Log-Likelihood:                -423.81
# No. Observations:                1163   AIC:                             869.6
# Df Residuals:                    1152   BIC:                             925.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.0178      0.008     -2.110      0.035      -0.034      -0.001
# APRENDIZ                   -0.0627      0.011     -5.954      0.000      -0.083      -0.042
# OBRERO                      0.2075      0.014     15.326      0.000       0.181       0.234
# COSTOS_PT_ELAB_TERCEROS     0.1354      0.013     10.587      0.000       0.110       0.160
# OUTSOURCING_PROD            0.0148      0.012      1.183      0.237      -0.010       0.039
# COMPRAS_MP_EXTERIOR        -0.0780      0.014     -5.398      0.000      -0.106      -0.050
# PUBLICIDAD_PROD            -0.0035      0.013     -0.269      0.788      -0.029       0.022
# GASTOSCARTERA              -0.0090      0.004     -2.110      0.035      -0.017      -0.001
# SEGUROS                     0.0172      0.013      1.282      0.200      -0.009       0.043
# TOTALINVER                  0.0298      0.012      2.504      0.012       0.006       0.053
# INV_PT                      0.0633      0.012      5.439      0.000       0.040       0.086
# MPCOMPRADA                  0.6649      0.016     41.619      0.000       0.634       0.696
# ==============================================================================
# Omnibus:                      464.391   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13676.301
# Skew:                           1.221   Prob(JB):                         0.00
# Kurtosis:                      19.621   Cond. No.                     5.88e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.3e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Teniendo en cuenta que el modelo anterior presenta heterocedasticidad se usa el Estimador Robusto de a la heterocedasticidad de White desarrollado en 1980 

#Se ejecuta el modelo final

est = ols(formula, total).fit(cov_type='HC0') #HCO=Heterocedasticidad usando Estimador de White

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 VENTAS   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.708
# Method:                 Least Squares   F-statistic:                     438.0
# Date:                Mon, 04 Mar 2019   Prob (F-statistic):               0.00
# Time:                        11:37:14   Log-Likelihood:                -171.44
# No. Observations:                1342   AIC:                             364.9
# Df Residuals:                    1331   BIC:                             422.1
# Df Model:                          10
# Covariance Type:                  HC0
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -0.0836      0.010     -8.086      0.000      -0.104      -0.063
# APRENDIZ                   -0.0235      0.013     -1.740      0.082      -0.050       0.003
# OBRERO                      0.1852      0.016     11.292      0.000       0.153       0.217
# COSTOS_PT_ELAB_TERCEROS     0.0686      0.017      4.072      0.000       0.036       0.102
# OUTSOURCING_PROD            0.0059      0.012      0.503      0.615      -0.017       0.029
# COMPRAS_MP_EXTERIOR        -0.0542      0.014     -3.786      0.000      -0.082      -0.026
# PUBLICIDAD_PROD             0.0023      0.009      0.242      0.809      -0.016       0.021
# GASTOSCARTERA              -0.0424      0.005     -8.086      0.000      -0.053      -0.032
# SEGUROS                     0.0172      0.019      0.914      0.361      -0.020       0.054
# TOTALINVER                 -0.0096      0.012     -0.812      0.417      -0.033       0.014
# INV_PT                      0.0194      0.021      0.926      0.355      -0.022       0.061
# MPCOMPRADA                  0.5472      0.037     14.606      0.000       0.474       0.621
# ==============================================================================
# Omnibus:                      310.507   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5044.896
# Skew:                           0.615   Prob(JB):                         0.00
# Kurtosis:                      12.418   Cond. No.                     1.72e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The smallest eigenvalue is 6.76e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
